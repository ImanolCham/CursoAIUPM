# %% [markdown]
# # Local Server con LLM Studio

# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI
import textwrap

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

completion = client.chat.completions.create(
  model="qwen3-0.6b",
  messages=[
    {"role": "system", "content": "Always answer in rhymes."},
    {"role": "user", "content": "what is your name."}
  ],
  temperature=0.7,
)


formatted_text = textwrap.fill(completion.choices[0].message.content, width=80)
print(formatted_text)
# Out:
#   I'm called Moonlight, so light, bright.   With stars in my sky, I shine.

# %%
prompt = f"""
Tell me about AeroGlide UltraSlim Smart Toothbrush by Boie. If you don't know about it, say so.
"""

completion = client.chat.completions.create(
  model="qwen3-0.6b",
  messages=[
    {"role": "system", "content": "answer in a concise way."},
    {"role": "user", "content": prompt}
  ],
  temperature=0.7,
)

formatted_text = textwrap.fill(completion.choices[0].message.content, width=80)
print(formatted_text)
# Out:
#   The AeroGlide UltraSlim Smart Toothbrush by Boie is a modern dental assistant
# designed for convenience and effectiveness in daily oral care. It features a
# sleek, ultra-slim design that combines advanced technology with intuitive smart
# capabilities, offering users improved hygiene control and ease of use. While
# specific details about its exact model or unique selling points may vary, it is
# a compact and user-friendly device aimed at enhancing dental health.
