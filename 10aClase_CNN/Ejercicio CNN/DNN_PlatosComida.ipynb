# %% [markdown]
# ### Ejercicio clasificación de platos de Comida para la clase 10/11 del módulo de CNN.

# %%
import os
import kagglehub
import h5py


os.environ["KAGGLEHUB_CACHE"] = r"C:\Users\Usuario\Documents\CursoAIUPM\10aClase_CNN\Ejercicio CNN\data"

dataset_path = kagglehub.dataset_download("kmader/food41")
print("Dataset en:", dataset_path)

files = os.listdir(dataset_path)
print("\nArchivos encontrados:")
for f in files:
    print(f)
