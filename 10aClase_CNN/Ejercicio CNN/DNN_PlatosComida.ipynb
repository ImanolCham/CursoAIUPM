# %% [markdown]
# ### Ejercicio clasificación de platos de Comida para la clase 10/11 del módulo de CNN.

# %% [markdown]
# La idea es entrenar un modelo que sirve para clasificar imágenes, asignar etiqueta a imagen completa. En este caso, que vea una imagen y sea capaz de detectar cuál es gracias al modelo que vamos a entrenar. Food-101 contiene 101 categorías con 101.000 imágenes, por lo que a través de esto se pueden detectar.

# %% [markdown]
# Recordatorio de que es una CNN:
# Es una red neuronal diseñada para imágenes, porque aprovecha la estructura espacial de los píxeles: alto, ancho y canales de color. En vez de tratar imagen como lista plana de números, aplica convoluciones para detectar patrones locales de varios tipos y luego usa pooling para reducir tamaño y quedarse con lo importante.
# Idea de como lo vamos a hacer y de cómo se vió en clase:
# 1. Primeras capas: detectan bordes y colores
# 2. Capas intermedias: detectan partes + complejas
# 3. Capas finales: combinan esas pistas para decidir la clase.

# %%
import os
import kagglehub
import h5py


os.environ["KAGGLEHUB_CACHE"] = r"C:\Users\Usuario\Documents\CursoAIUPM\10aClase_CNN\Ejercicio CNN\data"

dataset_path = kagglehub.dataset_download("kmader/food41")
print("Dataset en:", dataset_path)

files = os.listdir(dataset_path)
print("\nArchivos encontrados:")
for f in files:
    print(f)
