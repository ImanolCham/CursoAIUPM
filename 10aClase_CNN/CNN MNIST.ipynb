# %% [markdown]
# # CNN para clasificar MNIST
#
# Cargamos librerias y el dataset.
#
# Normalizamos las imágenes, redimensionamos a un canal y transformamos las etiquetas

# %%
import keras
from keras import layers, models
from keras.datasets import mnist
from keras.utils import to_categorical

# 1. Cargar y preprocesar el dataset MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalizar los valores de píxeles al rango [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Redimensionar las imágenes para que tengan un canal (escala de grises)
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))

# Convertir las etiquetas a one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)    
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (60000, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)
# y_train shape: (60000, 10)
# y_test shape: (10000, 10)

# %%
# 2. Definir la arquitectura del modelo CNN
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

# 3. Compilar el modelo
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 4. Entrenar el modelo
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test))

# 5. Evaluar el modelo
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Epoch 1/5
# c:\Users\igome\miniconda3\envs\AIAerospace\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.9390 - loss: 0.2031 - val_accuracy: 0.9777 - val_loss: 0.0674
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.9803 - loss: 0.0652 - val_accuracy: 0.9852 - val_loss: 0.0471
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.9858 - loss: 0.0464 - val_accuracy: 0.9870 - val_loss: 0.0417
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.9882 - loss: 0.0386 - val_accuracy: 0.9851 - val_loss: 0.0455
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.9905 - loss: 0.0313 - val_accuracy: 0.9862 - val_loss: 0.0417
# Test loss: 0.0416925884783268
# Test accuracy: 0.9861999750137329
