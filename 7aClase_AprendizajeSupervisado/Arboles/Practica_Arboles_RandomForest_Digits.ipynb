# %% [markdown]
# ## Práctica: Árboles de decisión, Random Forest y Digits (estilo MNIST)
#
# Vamos a usar `load_digits` de `sklearn` como sustituto ligero de MNIST.
#
# En esta práctica vas a:
#
# 1. Cargar y visualizar el dataset `load_digits`.
# 2. Preprocesar datos (split train/test y escalado **opcional**).
# 3. Entrenar y evaluar:
#    - **Árbol de decisión**
#    - **Random Forest**

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### Carga de Dataset Digits
#
# 1. Cargamos el dataset `load_digits` de `sklearn`.
#    - Contiene imágenes de dígitos manuscritos de tamaño 8x8.
#    - `X` estará en formato vector (64 características por imagen).
# 2. Mostramos algunas imágenes para comprobar el formato.

# %%
# Cargar dataset
digits = load_digits()
X = digits.data
y = digits.target

print("Dimensión del dataset:", X.shape)  # (n_muestras, 64)
print("Clases:", np.unique(y))

# Visualizar algunas imágenes
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for ax, idx in zip(axes.ravel(), range(10)):
    ax.imshow(digits.images[idx], cmap="gray")
    ax.set_title(f"Label: {y[idx]}")
    ax.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Preprocesamiento de datos
#
# 1. Dividimos el conjunto en entrenamiento y test (80%-20%).
#    - Usa `stratify=y` para mantener el balance de clases en ambos conjuntos.
# 2. **Escalado (opcional)**: en árboles NO es necesario, pero lo mantenemos por consistencia y para poder comparar con otras prácticas.

# %%
# ==========================================
# ToDo: Dividir en train/test y (opcional) estandarizar
# ==========================================

# 1. dividir en train y test (Usa stratify = y )
# X_train, X_test, y_train, y_test = 

print("Train:", X_train.shape)
print("Test:", X_test.shape)

# 2. Escalado (opcional)
# scaler = 
# X_train_scaled = 
# X_test_scaled =

# %% [markdown]
# ### Árbol de decisión
#
# En esta parte de la práctica debes:
#
# 1. Crear un modelo `DecisionTreeClassifier` (elige `max_depth` y/o `min_samples_leaf`).
# 2. Entrenarlo con `fit`.
# 3. Predecir el conjunto de test.
# 4. Evaluar el rendimiento (accuracy, matriz de confusión y/o classification report).
# 5. (Opcional) Visualizar el árbol con `plot_tree`.

# %%
# ================================
# ToDo: Entrenar y evaluar Árbol de decisión
# ================================

# 1. Crear el modelo (elige hiperparámetros)
# dt = 

# 2. Entrenar
# 

# 3. Predecir
# y_pred_dt = 

# 4. Evaluar
# acc_dt = accuracy_score(y_test, y_pred_dt)
print("Accuracy:", acc_dt)
print(confusion_matrix(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))

# 5. Visualizar
plt.figure(figsize=(14, 6))
plot_tree(dt, max_depth=3, filled=True)
plt.show()

# %% [markdown]
# ### Random Forest
#
# En esta parte de la práctica debes:
#
# 1. Crear un modelo `RandomForestClassifier` (elige `n_estimators`, `max_depth`, etc.).
# 2. Entrenarlo con `fit`.
# 3. Predecir el conjunto de test.
# 4. Evaluar el rendimiento (accuracy, matriz de confusión, classification report).
# 5. (Opcional) Analizar la importancia de características (`feature_importances_`).

# %%
# ================================
# ToDo: Entrenar y evaluar Random Forest
# ================================

# 1. Crear el modelo
# rf = 

# 2. Entrenar
# 

# 3. Predecir
# y_pred_rf = 

# 4. Evaluar
# acc_rf = 
print("Accuracy:", acc_rf)
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))

# 5. Importancias
importances = rf.feature_importances_
top_idx = np.argsort(importances)[::-1][:10]
for i in top_idx:
    print(i, importances[i])
